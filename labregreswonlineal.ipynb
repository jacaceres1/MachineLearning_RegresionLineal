# %% [markdown]
# # Importado de Librerias

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
from scipy import stats
import numpy as np

# %% [markdown]
# # Generación de los datos

# %%
def generate_data():
    """
        La función realiza la generación de la data 
    """
    mg = np.random.default_rng()
    x = mg.random(10)
    y = 1.6*x+mg.random(10)

# %%
"""
    Esta imprime el valor de x
"""
print(x)
print(__doc__)
# Out:
# [0.79356672 0.16003308 0.36888686 0.19442208 0.23773906 0.89304163
#  0.28816383 0.7328615  0.5903272  0.40848401]
#
#     Esta imprime el valor de x

# %%
print(y)
# Out:
# [1.64412585 1.16781654 1.57626784 0.37200981 0.57985325 2.14435555
#  1.01676533 2.04609456 1.77658589 1.00786048]

# %% [markdown]
# calcula la regresion lineal de minimos cuadrados

# %%
slope, intercept, r, p ,std_err = stats.linregress(x,y)

# %% [markdown]
# utilizar la funcion auxilitar que usa la pendiente e interseccion calculadas para devolver un nuevo valor

# %%
def fitted_value(x):
  return slope*x+intercept

# %% [markdown]
# calcular los valores ajustados para y

# %%
new_Values = list(map(fitted_value,x))

# %% [markdown]
# visualizacion del modelo

# %%
plt.plot(x,y,'o',label = 'original data')
plt.plot(x,new_Values,'r',label='fitted line')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
if __name__ == "__main__":
    generate_data()
    help(generate_data)
# Out:
# Help on function generate_data in module __main__:
#
# generate_data()
#     La función realiza la generación de la data
